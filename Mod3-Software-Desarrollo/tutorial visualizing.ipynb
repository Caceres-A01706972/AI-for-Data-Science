# %% [markdown]
# #Connect To Google drive

# %%
# from google.colab import drive

# drive.mount("/content/gdrive")  
# !pwd
# Out:
# Mounted at /content/gdrive
# /content

# %% [markdown]
# Move to folder

# %%
# %cd "/content/gdrive/MyDrive/Cursos y CADIs y Capacitaciones Impartidas/Concentración Inteligencia Artificial avanzada para la Ciencia de Datos/Bloque I/Desarrollo de software aplicado a la ciencia de datos/Code"
# !ls
# Out:
# /content/gdrive/MyDrive/Cursos y CADIs y Capacitaciones Impartidas/Concentración Inteligencia Artificial avanzada para la Ciencia de Datos/Bloque I/Desarrollo de software aplicado a la ciencia de datos/Code
# 'integration in PCA.ipynb'    'tutorial python-mysql.ipynb'
#  Iris.csv		      'tutorial scikit-learn.ipynb'
#  iris.data		      'tutorial scipy.ipynb'
#  iris.names		      'tutorial seaborn.ipynb'
# 'mySQL samples.txt'	      'tutorial visualizing.ipynb'
# 'titanic train.csv'	       wine.data
# 'tutorial numpy.ipynb'	       wine.names
# 'tutorial pandas .ipynb'       winequality-red.csv
# 'tutorial pythonMongo.ipynb'   winequality-red.gsheet

# %% [markdown]
# # Load Dataset
#
# dataframe (df) is the object where pandas stores the data, each colum is actualy a hash containing the name of the column a as a key and the array of values as the value for the key

# %%
import pandas as pd

df = pd.read_csv('../DataSets/iris.data')
df.columns = ["sepal length","sepal width","petal length","petal width", "class"]
df.head()
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 1           4.7          3.2           1.3          0.2  Iris-setosa
# 2           4.6          3.1           1.5          0.2  Iris-setosa
# 3           5.0          3.6           1.4          0.2  Iris-setosa
# 4           5.4          3.9           1.7          0.4  Iris-setosa

# %% [markdown]
# #Making some nice visuals

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **%matplotlib inline**   is used only in Jupter notebooks, you should not incude this in python .py programs.

# %%
# %matplotlib inline

# %% [markdown]
# Scatter plot is the basic plot we use to comaper two varibles in a visual way, it is the most used type of plot to detect outliers and quily visualize grouping of values.
#
# you can call on the basic plot attribute of a dataframe which in turn calls the plot function of matplotlib.
#
# the sintax is:
#
#     dataframe.plot(name of column 1, name of column 2, kind ='scatter')

# %%
df.plot('sepal length', 'sepal width', kind ='scatter')
# Out:
# <AxesSubplot: xlabel='sepal length', ylabel='sepal width'>

# %% [markdown]
# Histogram is used whenver we want to visualize repetitions of ocurrences for example, how many times does a value repear in a variable. In this case how many time does a value show for each attribute. So value number 3 is the most recurring value in the data set for the sepal width variable.
#
#
# the sintax is:
#
#     dataframe.plot(kind ='hist', alpha = degree of transparency)

# %%
df.plot(kind ='hist', alpha = 0.3)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %% [markdown]
# Line plots or just "plots" follow the value of separate variable in a line. This are useful when we wish to compare sequences, for example performance of machine learning algorithms through trainning. In this case we case that each of the attributes behave differently at particular segment, each segment refect an specific class. For line plots to make sense, the usually need to be order, if you just plot the randomly they will look like noise.
#
# the sintax is:
#
#     dataframe.plot()

# %%
df.plot()
# Out:
# <AxesSubplot: >

# %% [markdown]
# Scatter Matrix is a matrix of individua scatter plots across the full datafame. These are very usefull when you are searching for patterns in the data which you can visualy recognize.

# %%
pd.plotting.scatter_matrix(df);

# %% [markdown]
# ### Practice Ploting using Matplotlib
#
# Download and upload a dataset from Kaggle, create a dataframe containing the dataset and search for:
#
#  * patterns using a scatter plot matrix
#  * outliers using a scatter plot
#  * most repeated values in a variable using a histogram
#  * sort the values by a spcific variable and then generate a plot (line)

# %%
# Upload data set into a dataframe
columns = ["class","Alcohol","Malic Acid", "Ash", "Alcalinity of Ash","Magnesium","Total phenols","Flavanoids","Nonflavanoid Phenols","Proanthocyanins","Color Intensity","Hue","OD280/OD315 of diluted wines","Proline"]
df = pd.read_csv('../DataSets/wine.data',names = columns)
df_wines = df[['Alcohol', 'Malic Acid', 'Color Intensity', 'Hue']]
df_wines.head()
# Out:
#    Alcohol  Malic Acid  Color Intensity   Hue
# 0    14.23        1.71             5.64  1.04
# 1    13.20        1.78             4.38  1.05
# 2    13.16        2.36             5.68  1.03
# 3    14.37        1.95             7.80  0.86
# 4    13.24        2.59             4.32  1.04

# %%
# Draw a Scatter plot matrix
pd.plotting.scatter_matrix(df_wines);

# %%
# Draw a scatter plot
df_wines.plot('Alcohol', 'Color Intensity', kind ='scatter')
# Out:
# <AxesSubplot: xlabel='Alcohol', ylabel='Color Intensity'>

# %%
# Draw a histogram
df_wines.plot(kind ='hist', alpha = 0.3)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
# Draw a plot
df_wines.plot()
# Out:
# <AxesSubplot: >

# %% [markdown]
# # MatplotLib Examples
# taken from [Matplotlib API](https://matplotlib.org/stable/tutorials/introductory/pyplot.html)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1, 2, 3, 4])
plt.ylabel('some numbers')
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
plt.axis([0, 6, 0, 20])
plt.show()

# %% [markdown]
# ### Plotting with keyword strings
# There are some instances where you have data in a format that lets you access particular variables with strings. For example, with numpy.recarray or pandas.DataFrame.
#
# Matplotlib allows you provide such an object with the data keyword argument. If provided, then you may generate plots with the strings corresponding to these variables.

# %%
import numpy as np

data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

#plt.scatter('name_x', 'name_y', c='color', s='size', data=data)

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %% [markdown]
# ### Plotting with categorical variables
#
# It is also possible to create a plot using categorical variables. Matplotlib allows you to pass categorical variables directly to many plotting functions. For example:

# %%
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

plt.figure(figsize=(9, 3))

plt.subplot(131)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
plt.show()

# %% [markdown]
# ## Practice Plots with pyplot
#
# Use the dataset you loaded previously and try to mix 4 varibles into the same plot:
#
#
# 1.   x
# 2.   y
# 3.   color
# 4.   size

# %%
# load data set
df_wines

# make a scatter plot

#plt.scatter('name_x', 'name_y', c='color', s='size', data=data)
plt.scatter('Alcohol', 'Malic Acid', c='blue', s='Alcohol', data=df_wines)
plt.xlabel('Alcohol')
plt.ylabel('Malic Acid')
plt.show()

# %% [markdown]
# Generate a histogram of the categorical values of an attribute of your data set.  Remember to use count from pandas

# %%
# get the column with categorical values
df_categories = df['class']

# count the repetition of each value
categorical_counts = df_categories.value_counts()

# make the histogram with a bar chart
categorical_counts.plot(kind='bar')
# Out:
# <AxesSubplot: >

# %% [markdown]
# Generate a histogram of the NA values in your dataframe.

# %%
# Get the NA values from the data
NA_values = df_wines.isna().sum()

# make the histograma with a bar chart
NA_values.hist()
# Out:
# <AxesSubplot: >
